# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir('/home/ubuntu/DA/dataframe')

# %%
hiphop_df = pd.read_csv('hiphop_df.csv')
hiphop_df = hiphop_df[hiphop_df.columns.drop(list(hiphop_df.filter(regex='Unnamed')))]

# %%
hiphop_df.to_csv('hiphop_df.csv')
hiphop_df
# Out:
#                                                  song    genre  \
# 0   SUPERBEE(수퍼비)  - 수퍼비와 (Feat. BewhY) (Prod. Bew...  hip-hop
# 1   창모 (CHANGMO), 해쉬스완 (Hash Swan), 애쉬 아일랜드 (ASH I...  hip-hop
# 2   프라이머리  - 독 (Feat. E Sens of 슈프림팀) 가사-QuC_EqHjA...  hip-hop
# 3   기리보이, Kid Milli, NOEL, 스윙스  - flex (Prod.By 기리...  hip-hop
# 4   슈퍼비 (SUPERBEE)  - +82 Bars [Rap Legend]-1-sg3f...  hip-hop
# 5   Jvcki Wai, 영비, Osshun Gum, 한요한  - 띵 (Prod.By 기...  hip-hop
# 6                          창모 (CHANGMO)  - METEOR.mp3  hip-hop
# 7               염따  - 돈 Call Me (Prod. by BRLLNT).mp3  hip-hop
# 8       HAON  - 붕붕(Feat. Sik-K)(Prod. GroovyRoom).mp3  hip-hop
# 9                            창모 (CHANGMO)  - 아름다워.mp3  hip-hop
# 10                       BTS (Suga)  - First Love.mp3  hip-hop
#
#                                                singer  \
# 0                                      SUPERBEE(수퍼비)
# 1   창모 (CHANGMO), 해쉬스완 (Hash Swan), 애쉬 아일랜드 (ASH I...
# 2                                              프라이머리
# 3                         기리보이, Kid Milli, NOEL, 스윙스
# 4                                     슈퍼비 (SUPERBEE)
# 5                     Jvcki Wai, 영비, Osshun Gum, 한요한
# 6                                       창모 (CHANGMO)
# 7                                                 염따
# 8                                               HAON
# 9                                       창모 (CHANGMO)
# 10                                        BTS (Suga)
#
#                                 title    tempo1    tempo2  mean_ft1   var_ft1  \
# 0   수퍼비와 (Feat. BewhY) (Prod. BewhY)   0.603396  0.622161  0.231829  0.286617
# 1                                BAND  1.000000  1.000000  0.356316  0.524990
# 2           독 (Feat. E Sens of 슈프림팀)   0.675593  0.806999  0.257873  0.277057
# 3                 flex (Prod.By 기리보이)  0.801678  0.801678  0.277787  0.486164
# 4                           +82 Bars   0.851034  0.851034  0.296003  0.507908
# 5                    띵 (Prod.By 기리보이)  0.857905  0.857905  0.286763  0.531600
# 6                              METEOR  0.887935  0.539090  0.243533  0.439929
# 7         돈 Call Me (Prod. by BRLLNT)  1.000000  1.000000  0.351372  0.420514
# 8   붕붕(Feat. Sik-K)(Prod. GroovyRoom)  0.815228  0.815228  0.290808  0.444963
# 9                                아름다워  0.635858  0.635858  0.292772  0.443060
# 10                         First Love  0.606470  0.516487  0.236680  0.258326
#
#     mean_ft2   var_ft2         ...           mean_chroma2  var_chroma2  \
# 0   0.237273  0.492815         ...               0.229405     0.228330
# 1   0.357391  0.590677         ...               0.351171     0.349527
# 2   0.262706  0.373651         ...               0.256465     0.255394
# 3   0.280453  0.549046         ...               0.268682     0.267598
# 4   0.297812  0.568082         ...               0.286934     0.285561
# 5   0.286730  0.537092         ...               0.277234     0.276050
# 6   0.244407  0.447080         ...               0.237971     0.237057
# 7   0.353645  0.466139         ...               0.348848     0.347067
# 8   0.292231  0.504227         ...               0.283599     0.282551
# 9   0.294124  0.455556         ...               0.287659     0.286650
# 10  0.238978  0.275813         ...               0.234958     0.233939
#
#     mean_mfccs1  var_mfccs1  mean_mfccs2  var_mfccs2  zero_crossings_mean1  \
# 0      0.229607    0.228160     0.229688    0.228168              0.228400
# 1      0.351379    0.349271     0.351333    0.349254              0.349737
# 2      0.256923    0.255183     0.256891    0.255180              0.255480
# 3      0.269073    0.267342     0.269178    0.267329              0.267762
# 4      0.287243    0.285314     0.287319    0.285309              0.285793
# 5      0.277604    0.275805     0.277679    0.275803              0.276225
# 6      0.238433    0.236840     0.238434    0.236843              0.237035
# 7      0.348816    0.346813     0.349007    0.346792              0.347106
# 8      0.284261    0.282301     0.284178    0.282286              0.282596
# 9      0.288265    0.286380     0.288271    0.286376              0.286601
# 10     0.235306    0.233768     0.235326    0.233759              0.234080
#
#     zero_crossings_var1  zero_crossings_mean2  zero_crossings_var2
# 0              0.228368              0.228308             0.228292
# 1              0.349656              0.349628             0.349574
# 2              0.255437              0.255468             0.255427
# 3              0.267689              0.267780             0.267701
# 4              0.285706              0.285753             0.285678
# 5              0.276152              0.276226             0.276153
# 6              0.237012              0.237032             0.237009
# 7              0.347065              0.347243             0.347172
# 8              0.282555              0.282625             0.282577
# 9              0.286574              0.286687             0.286643
# 10             0.234030              0.234115             0.234056
#
# [11 rows x 38 columns]

# %%
balad_df = pd.read_csv('balad_df.csv')
balad_df = balad_df[balad_df.columns.drop(list(balad_df.filter(regex='Unnamed')))]

# %%
balad_df.to_csv('balad_df.csv')
balad_df
# Out:
#                                song  genre           singer           title  \
# 0           정승환  -  언제라도 어디에서라도.mp3  balad             정승환      언제라도 어디에서라도
# 1     마크툽(MAKTUB),이라온 - 별을 담은 시.mp3  balad  마크툽(MAKTUB),이라온         별을 담은 시
# 2   로이킴 (Roy Kim)   -   살아가는 거야.mp3  balad  로이킴 (Roy Kim)           살아가는 거야
# 3              임창정   -   소주 한 잔.mp3  balad            임창정            소주 한 잔
# 4             Buzz   -   남자를 몰라.mp3  balad           Buzz            남자를 몰라
# 5  4MEN (포맨)   -   못해 (feat. 美).mp3  balad      4MEN (포맨)      못해 (feat. 美)
# 6      Paul Kim(폴킴)   -   너를 만나.mp3  balad   Paul Kim(폴킴)             너를 만나
# 7   노을   -   만약에 말야-96rbyrvhwME.mp3  balad             노을            만약에 말야
# 8          박효신   -   추억은 사랑을 닮아.mp3  balad            박효신        추억은 사랑을 닮아
#
#      tempo1    tempo2  mean_ft1   var_ft1  mean_ft2   var_ft2  \
# 0  0.702465  0.702465  0.308541  0.401742  0.311656  0.519327
# 1  0.669832  0.669832  0.302170  0.395739  0.307564  0.570422
# 2  0.664583  0.459114  0.245700  0.310583  0.247041  0.353630
# 3  0.759023  0.503499  0.249898  0.272434  0.254752  0.376615
# 4  0.520623  0.802143  0.242276  0.277212  0.246773  0.353780
# 5  1.000000  0.629920  0.262370  0.301007  0.267256  0.419801
# 6  0.878938  0.846274  0.292228  0.304104  0.294613  0.371602
# 7  0.772905  0.820135  0.302727  0.332749  0.305141  0.445472
# 8  0.799577  0.773925  0.287502  0.294436  0.290116  0.337061
#
#           ...           mean_chroma2  var_chroma2  mean_mfccs1  var_mfccs1  \
# 0         ...               0.305886     0.305206     0.306827    0.304981
# 1         ...               0.299335     0.298413     0.299923    0.298184
# 2         ...               0.243831     0.243109     0.244477    0.242933
# 3         ...               0.249207     0.248286     0.249662    0.248080
# 4         ...               0.240224     0.239390     0.240720    0.239196
# 5         ...               0.260871     0.260155     0.261582    0.259952
# 6         ...               0.291962     0.291331     0.292914    0.291095
# 7         ...               0.301484     0.300956     0.302594    0.300717
# 8         ...               0.287603     0.286889     0.288467    0.286661
#
#    mean_mfccs2  var_mfccs2  zero_crossings_mean1  zero_crossings_var1  \
# 0     0.306906    0.304978              0.305083             0.305070
# 1     0.300006    0.298167              0.298312             0.298297
# 2     0.244499    0.242921              0.243005             0.242996
# 3     0.249664    0.248061              0.248210             0.248194
# 4     0.240805    0.239188              0.239399             0.239372
# 5     0.261557    0.259931              0.260123             0.260100
# 6     0.292976    0.291102              0.291216             0.291203
# 7     0.302573    0.300726              0.300793             0.300784
# 8     0.288444    0.286656              0.286706             0.286700
#
#    zero_crossings_mean2  zero_crossings_var2
# 0              0.305129             0.305110
# 1              0.298392             0.298365
# 2              0.242986             0.242979
# 3              0.248275             0.248248
# 4              0.239472             0.239431
# 5              0.260191             0.260155
# 6              0.291231             0.291216
# 7              0.300852             0.300837
# 8              0.286784             0.286769
#
# [9 rows x 38 columns]

# %%
RB_df = pd.read_csv('RB_df.csv')
RB_df = RB_df[RB_df.columns.drop(list(RB_df.filter(regex='Unnamed')))]

# %%
RB_df.to_csv('RB_df.csv')
RB_df
# Out:
#                                                 song genre  \
# 0   IU(아이유)  - Palette(팔레트) (Feat. G-DRAGON)-d9Ix...   R&B
# 1                             헤이즈 (Heize)  - 저 별.mp3   R&B
# 2  [Audio] 아이유  - 사랑이 잘 (With. 오혁), IU - Can‘t Lo...   R&B
# 3      JIDA  - Autumn Breeze (Feat - Rachel Lim).mp3   R&B
# 4    Dean  - D (Half Moon) ft. Gaeko-eelfrHtmk68.mp3   R&B
# 5                             폴킴 (Paul Kim)  - 비.mp3   R&B
# 6   Urban Zakapa(어반자카파)  - Thursday Night(목요일 밤) ...   R&B
# 7                     Adele  - Hello-YQHsXMglC9A.mp3   R&B
# 8  Sam Smith  - I'm Not The Only One (Official Vi...   R&B
#
#                   singer                                        title  \
# 0               IU(아이유)                         Palette(팔레트) (Feat. G
# 1           헤이즈 (Heize)                                           저 별
# 2           [Audio] 아이유                                    사랑이 잘 , IU
# 3                  JIDA                           Autumn Breeze (Feat
# 4                  Dean                                  D  ft. Gaeko
# 5         폴킴 (Paul Kim)                                             비
# 6   Urban Zakapa(어반자카파)   Thursday Night(목요일 밤) (feat. Beenzino(빈지노))
# 7                 Adele                                         Hello
# 8             Sam Smith                         I'm Not The Only One
#
#      tempo1    tempo2  mean_ft1   var_ft1  mean_ft2   var_ft2  \
# 0  0.700961  0.700961  0.301484  0.439364  0.305140  0.533640
# 1  0.702598  0.634234  0.334895  0.379225  0.339049  0.531340
# 2  0.729225  0.503145  0.272047  0.428270  0.273714  0.500170
# 3  0.527858  0.796530  0.264387  0.420678  0.266787  0.530529
# 4  0.990557  0.990557  0.307657  0.474559  0.311668  0.661248
# 5  0.763509  0.489833  0.267492  0.298678  0.273015  0.544709
# 6  0.578529  0.578529  0.269959  0.426698  0.271783  0.456713
# 7  1.000000  0.918866  0.310753  0.311103  0.311611  0.323407
# 8  0.658967  0.658967  0.321138  0.358278  0.325543  0.524944
#
#           ...           mean_chroma2  var_chroma2  mean_mfccs1  var_mfccs1  \
# 0         ...               0.297090     0.296195     0.297828    0.295909
# 1         ...               0.332970     0.331879     0.333753    0.331612
# 2         ...               0.266421     0.265504     0.266921    0.265272
# 3         ...               0.260219     0.259502     0.260930    0.259300
# 4         ...               0.302873     0.301734     0.303389    0.301507
# 5         ...               0.266918     0.266225     0.267677    0.266006
# 6         ...               0.264960     0.264051     0.265469    0.263827
# 7         ...               0.311855     0.310757     0.312462    0.310449
# 8         ...               0.320982     0.319778     0.321540    0.319495
#
#    mean_mfccs2  var_mfccs2  zero_crossings_mean1  zero_crossings_var1  \
# 0     0.297757    0.295913              0.296131             0.296105
# 1     0.333800    0.331597              0.331877             0.331842
# 2     0.266935    0.265257              0.265569             0.265524
# 3     0.260883    0.259281              0.259434             0.259417
# 4     0.303499    0.301455              0.301716             0.301686
# 5     0.267664    0.266009              0.266048             0.266043
# 6     0.265485    0.263812              0.264001             0.263980
# 7     0.312446    0.310482              0.310645             0.310625
# 8     0.321540    0.319495              0.319630             0.319616
#
#    zero_crossings_mean2  zero_crossings_var2
# 0              0.296185             0.296149
# 1              0.331858             0.331826
# 2              0.265513             0.265480
# 3              0.259437             0.259419
# 4              0.301660             0.301638
# 5              0.266088             0.266079
# 6              0.264032             0.264005
# 7              0.310621             0.310604
# 8              0.319591             0.319581
#
# [9 rows x 38 columns]

# %%
pop_df = pd.read_csv('pop_df.csv')
pop_df = pop_df[pop_df.columns.drop(list(pop_df.filter(regex='Unnamed')))]

# %%
pop_df.to_csv('pop_df.csv')
pop_df
# Out:
#                                                 song genre             singer  \
# 0  Maroon 5  - Sugar (Official Music Video)-09R8_...   pop          Maroon 5
# 1  Carly Rae Jepsen  - Call Me Maybe-fWNaR-rxAic.mp3   pop  Carly Rae Jepsen
# 2  Sia  - Chandelier (Official Video)-2vjPBrBU-TM...   pop               Sia
# 3  Mark Ronson  - Uptown Funk (Official Video) ft...   pop       Mark Ronson
# 4  Ed Sheeran  - Shape of You (Official Music Vid...   pop        Ed Sheeran
# 5  Wiz Khalifa  - See You Again ft. Charlie Puth ...   pop       Wiz Khalifa
# 6                         The Wanted  - Glad You.mp3   pop        The Wanted
# 7  Cheryl Cole  - Fight For This Love (Official V...   pop       Cheryl Cole
#
#                              title    tempo1    tempo2  mean_ft1   var_ft1  \
# 0                           Sugar   0.723919  0.703593  0.279359  0.309549
# 1                    Call Me Maybe  0.851416  0.851416  0.332748  0.370765
# 2                      Chandelier   0.596262  0.498189  0.233750  0.343290
# 3                     Uptown Funk   0.896786  0.896786  0.357311  0.446072
# 4                    Shape of You   0.727684  0.727684  0.269009  0.433596
# 5  See You Again ft. Charlie Puth   1.000000  1.000000  0.324661  0.479942
# 6                         Glad You  0.702532  0.702532  0.257123  0.263829
# 7             Fight For This Love   0.928821  0.928821  0.356185  0.363833
#
#    mean_ft2   var_ft2         ...           mean_chroma2  var_chroma2  \
# 0  0.285545  0.461609         ...               0.278134     0.277088
# 1  0.333248  0.375171         ...               0.330619     0.329151
# 2  0.238195  0.459404         ...               0.229638     0.228753
# 3  0.361136  0.496394         ...               0.353395     0.351549
# 4  0.271510  0.505465         ...               0.263846     0.262986
# 5  0.326814  0.531877         ...               0.320974     0.319922
# 6  0.258882  0.281741         ...               0.256740     0.255597
# 7  0.357075  0.368954         ...               0.355636     0.354337
#
#    mean_mfccs1  var_mfccs1  mean_mfccs2  var_mfccs2  zero_crossings_mean1  \
# 0     0.278667    0.276829     0.278626    0.276844              0.277042
# 1     0.331018    0.328875     0.330874    0.328876              0.329240
# 2     0.230203    0.228598     0.230228    0.228574              0.228785
# 3     0.353535    0.351257     0.353547    0.351247              0.351855
# 4     0.264521    0.262762     0.264575    0.262745              0.262949
# 5     0.321687    0.319613     0.321678    0.319610              0.319767
# 6     0.257108    0.255392     0.257309    0.255384              0.255715
# 7     0.356284    0.354053     0.356254    0.354033              0.354490
#
#    zero_crossings_var1  zero_crossings_mean2  zero_crossings_var2
# 0             0.277019              0.277122             0.277084
# 1             0.329188              0.329307             0.329239
# 2             0.228756              0.228820             0.228785
# 3             0.351746              0.351866             0.351753
# 4             0.262926              0.262954             0.262930
# 5             0.319750              0.319781             0.319762
# 6             0.255664              0.255680             0.255638
# 7             0.354422              0.354511             0.354437
#
# [8 rows x 38 columns]

# %%
kpop_df = pd.read_csv('kpop_df.csv')
kpop_df = kpop_df[kpop_df.columns.drop(list(kpop_df.filter(regex='Unnamed')))]

# %%
kpop_df.to_csv('kpop_df.csv')
kpop_df
# Out:
#                          song  genre            singer        title    tempo1  \
# 0    TWICE  - KNOCK KNOCK.mp3  k-pop            TWICE   KNOCK KNOCK  0.715948
# 1          BIGBANG  - 맨정신.mp3  k-pop          BIGBANG           맨정신  0.639326
# 2  블랙핑크(BLACKPINK)  - 불장난.mp3  k-pop  블랙핑크(BLACKPINK)           불장난  0.592799
# 3                 숀  - 습관.mp3  k-pop                숀            습관  0.730583
# 4              마마무  - HIP.mp3  k-pop              마마무           HIP  0.806113
# 5      BIGBANG  - 에라 모르겠다.mp3  k-pop          BIGBANG       에라 모르겠다  0.729608
# 6               선미  - 주인공.mp3  k-pop               선미           주인공  0.861718
# 7       마마무  -  Piano Man.mp3  k-pop              마마무     Piano Man  0.676752
#
#      tempo2  mean_ft1   var_ft1  mean_ft2   var_ft2         ...           \
# 0  0.715948  0.265519  0.527378  0.269911  0.614415         ...
# 1  0.639326  0.233048  0.485984  0.235052  0.521900         ...
# 2  0.592799  0.262353  0.422785  0.264083  0.469230         ...
# 3  0.730583  0.289873  0.468395  0.293181  0.566018         ...
# 4  0.806113  0.293312  0.636589  0.296014  0.687789         ...
# 5  0.729608  0.341367  0.525564  0.346687  0.613889         ...
# 6  0.861718  0.333412  0.481161  0.339565  0.586823         ...
# 7  0.676752  0.275645  0.338480  0.282873  0.485811         ...
#
#    mean_chroma2  var_chroma2  mean_mfccs1  var_mfccs1  mean_mfccs2  \
# 0      0.256387     0.255237     0.256686    0.255030     0.256672
# 1      0.224044     0.222986     0.224429    0.222815     0.224632
# 2      0.255802     0.254781     0.256212    0.254565     0.256266
# 3      0.283685     0.282636     0.284290    0.282380     0.284259
# 4      0.285490     0.284156     0.285863    0.283900     0.285704
# 5      0.333143     0.331956     0.333947    0.331633     0.333767
# 6      0.328011     0.326832     0.328748    0.326594     0.328737
# 7      0.273399     0.272433     0.273943    0.272194     0.273908
#
#    var_mfccs2  zero_crossings_mean1  zero_crossings_var1  \
# 0    0.255021              0.255335             0.255290
# 1    0.222792              0.223021             0.222992
# 2    0.254548              0.254839             0.254798
# 3    0.282368              0.282628             0.282596
# 4    0.283898              0.284137             0.284107
# 5    0.331641              0.332099             0.332024
# 6    0.326560              0.326832             0.326797
# 7    0.272188              0.272301             0.272290
#
#    zero_crossings_mean2  zero_crossings_var2
# 0              0.255418             0.255353
# 1              0.223056             0.223020
# 2              0.254875             0.254826
# 3              0.282631             0.282598
# 4              0.284141             0.284110
# 5              0.332232             0.332119
# 6              0.327027             0.326949
# 7              0.272533             0.272482
#
# [8 rows x 38 columns]

# %%
total_df = pd.concat([hiphop_df, balad_df, RB_df, pop_df, kpop_df])
total_df = total_df.reset_index()
total_df.drop(columns = 'index', inplace = True)
total_df.to_csv('total_df.csv', index = False)

# %%
len(total_df.columns)
# Out:
# 38
